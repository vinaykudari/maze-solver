# %%
import gym
import torch
import torch.nn as nn
import numpy as np
from collections import deque
import random
from itertools import count
import torch.nn.functional as F
import os

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class QNetwork(nn.Module):
    def __init__(self):
        super(QNetwork, self).__init__()

        self.fc1 = nn.Linear(4, 32) #4 states
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(32, 256) #hidden layer with 32 outputs and inputs
        self.fc3 = nn.Linear(256, 2) #2 actions

    def forward(self, state):
        y = self.relu(self.fc1(state))
        y = self.relu(self.fc2(y))
        Q = self.fc3(y)

        return Q

    #returns state with highest Q value
    def select_action(self, state):
        with torch.no_grad():
            Q = self.forward(state)
            action_index = torch.argmax(Q, dim=1)
        return action_index.item()


# The official Pytorch documentation has a class implementation of the ReplayBuffer. The implementation inspired me to make something and hence it is similar to the official one.

class Memory(object):
    def __init__(self, buffer_size: int) -> None:
        self.buffer_size = buffer_size
        self.buffer = deque(maxlen=self.buffer_size)

    def add(self, experience) -> None:
        self.buffer.append(experience)

    def size(self):
        return len(self.buffer)

    #making random memory
    def sample(self, batch_size: int, continuous: bool = True):
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
            #continuous floats
        if continuous:
            rand = random.randint(0, len(self.buffer) - batch_size) #return 
            return [self.buffer[i] for i in range(rand, rand + batch_size)]
          #random ints
        else:
            indexes = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False) #return int the size of buffer
            return [self.buffer[i] for i in indexes]

    def clear(self):
        self.buffer.clear()


# Cartpole-v1 is solved when:
#     max_episode_steps=500,
#     reward_threshold=475.0

env = gym.make('CartPole-v1')
n_state = env.observation_space.shape[0]
n_action = env.action_space.n

onlineQNetwork = QNetwork().to(device)

if(os.path.isfile('dqn-policy.pt')):
  onlineQNetwork.load_state_dict(torch.load('dqn-policy.pt'))

targetQNetwork = QNetwork().to(device)
targetQNetwork.load_state_dict(onlineQNetwork.state_dict())


#Optimizer




# Hyperparameters 
GAMMA = 0.99
INITIAL_EPSILON = 0.9 #epsilon starting value
FINAL_EPSILON = 0.001 # minimum value of epsilon
EPSILON_DECAY = 0.980 # decay
BUFFER_SIZE = 50000 # size of replay buffer
BATCH = 128 # minibatch size
LR = 1e-4

# Using Adam with a Learning Rate of 0.0001
optimizer = torch.optim.Adam(onlineQNetwork.parameters(), lr=LR)

#Flow:
# Loop till done else break
# Select action based on epsilon
# Take action
# Add result to replay buffer
# If buffer size > minibatch (Train TargetNet every 1000 steps)
# Update Q network
# Perform Loss
# Perform Epsilon Decay



UPDATE_EVERY = 1000 # tau


# graphing
totalreward=[]
losses = []

replay_buffer = Memory(BUFFER_SIZE)

epsilon = INITIAL_EPSILON
steps = 0

episode_reward = 0

for epoch in count():

    state = env.reset()
    episode_reward = 0
    episode_loss = 0
    for time_steps in range(5000): #env states max 500 steps allowed
        p = random.random()
        if p < epsilon:
            action = random.randint(0, 1) #random action
        else:
            tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
            action = onlineQNetwork.select_action(tensor_state)               #argmax action
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward
        replay_buffer.add((state, next_state, action, reward, done))
        if replay_buffer.size() > 128:
            steps += 1

            # updating target network over every 1000 steps (OpenAIBaseline)
            if steps % UPDATE_EVERY == 0:
                targetQNetwork.load_state_dict(onlineQNetwork.state_dict())  # copy q network state to target network every 1000 steps
                print("Updating Target Net")
            experience = replay_buffer.sample(BATCH, False)
            exp_state, exp_next_state, exp_action, exp_reward, exp_done = zip(*experience)
            # 'Unzipping' individual tuples

            #Converting experience to Tensors 

            exp_state = torch.FloatTensor(exp_state).to(device)
            exp_next_state = torch.FloatTensor(exp_next_state).to(device)
            exp_action = torch.FloatTensor(exp_action).unsqueeze(1).to(device)
            exp_reward = torch.FloatTensor(exp_reward).unsqueeze(1).to(device)
            exp_done = torch.FloatTensor(exp_done).unsqueeze(1).to(device)

            with torch.no_grad():
                targetQ_next = targetQNetwork(exp_next_state)
                y = exp_reward + (1 - exp_done) * GAMMA * torch.max(targetQ_next, dim=1, keepdim=True)[0] #DQN Update step


            # Simple MSE Loss
            loss = F.mse_loss(onlineQNetwork(exp_state).gather(1, exp_action.long()), y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            episode_loss+= loss
            
            # epsilon decay
            if epsilon > FINAL_EPSILON:
                epsilon *= EPSILON_DECAY
            else:
                epsilon = FINAL_EPSILON

        if done:
            break
        state = next_state
      
    if epoch==1000: #for the purpose of a test run else could run till infinity
      break

    totalreward.append(episode_reward)
    losses.append(episode_loss)
    if epoch % 10 == 0:
        torch.save(onlineQNetwork.state_dict(), 'dqn-policy.pt') #saving learning policy every 10 epochs
        print(f'Ep {epoch} Average Reward: {episode_reward} Ep Loss: {episode_loss}')
# Out:
# Ep 0 Average Reward: 11.0 Ep Loss: 0
# Ep 10 Average Reward: 12.0 Ep Loss: 0.16352364420890808
# Ep 20 Average Reward: 9.0 Ep Loss: 0.09130951762199402
# Ep 30 Average Reward: 9.0 Ep Loss: 0.024008555337786674
# Ep 40 Average Reward: 9.0 Ep Loss: 0.013921874575316906
# Ep 50 Average Reward: 9.0 Ep Loss: 0.009180630557239056
# Ep 60 Average Reward: 10.0 Ep Loss: 0.010346191935241222
# Ep 70 Average Reward: 9.0 Ep Loss: 0.006054366007447243
# Ep 80 Average Reward: 9.0 Ep Loss: 0.006788790225982666
# Updating Target Net
# Ep 90 Average Reward: 10.0 Ep Loss: 0.9831762313842773
# Ep 100 Average Reward: 10.0 Ep Loss: 0.4836290180683136
# Ep 110 Average Reward: 10.0 Ep Loss: 0.5013114213943481
# Ep 120 Average Reward: 8.0 Ep Loss: 0.36781391501426697
# Ep 130 Average Reward: 10.0 Ep Loss: 0.46810275316238403
# Ep 140 Average Reward: 10.0 Ep Loss: 0.4860062599182129
# Ep 150 Average Reward: 10.0 Ep Loss: 0.49766314029693604
# Ep 160 Average Reward: 10.0 Ep Loss: 0.49029284715652466
# Ep 170 Average Reward: 10.0 Ep Loss: 0.38754013180732727
# Ep 180 Average Reward: 10.0 Ep Loss: 0.43770119547843933
# Updating Target Net
# Ep 190 Average Reward: 8.0 Ep Loss: 3.957152843475342
# Ep 200 Average Reward: 8.0 Ep Loss: 0.8613656759262085
# Ep 210 Average Reward: 10.0 Ep Loss: 1.0694091320037842
# Ep 220 Average Reward: 10.0 Ep Loss: 0.863072395324707
# Ep 230 Average Reward: 9.0 Ep Loss: 0.7618873715400696
# Ep 240 Average Reward: 10.0 Ep Loss: 0.7598597407341003
# Ep 250 Average Reward: 8.0 Ep Loss: 0.6526107788085938
# Ep 260 Average Reward: 8.0 Ep Loss: 0.6528270244598389
# Ep 270 Average Reward: 10.0 Ep Loss: 0.8188337087631226
# Ep 280 Average Reward: 10.0 Ep Loss: 0.8767663836479187
# Ep 290 Average Reward: 10.0 Ep Loss: 0.6087523698806763
# Updating Target Net
# Ep 300 Average Reward: 8.0 Ep Loss: 1.0768988132476807
# Ep 310 Average Reward: 10.0 Ep Loss: 0.8295196294784546
# Ep 320 Average Reward: 10.0 Ep Loss: 0.8496902585029602
# Ep 330 Average Reward: 10.0 Ep Loss: 0.8337476253509521
# Ep 340 Average Reward: 10.0 Ep Loss: 0.7439306974411011
# Ep 350 Average Reward: 11.0 Ep Loss: 0.7708150148391724
# Ep 360 Average Reward: 9.0 Ep Loss: 0.7022157907485962
# Ep 370 Average Reward: 11.0 Ep Loss: 0.6995006799697876
# Ep 380 Average Reward: 9.0 Ep Loss: 0.5461302399635315
# Ep 390 Average Reward: 10.0 Ep Loss: 0.5567378997802734
# Updating Target Net
# Ep 400 Average Reward: 8.0 Ep Loss: 0.5435414910316467
# Ep 410 Average Reward: 9.0 Ep Loss: 0.5583997368812561
# Ep 420 Average Reward: 9.0 Ep Loss: 0.5461276769638062
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 430 Average Reward: 109.0 Ep Loss: 17.7232723236084
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 440 Average Reward: 500.0 Ep Loss: 130.6453857421875
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 450 Average Reward: 500.0 Ep Loss: 252.44960021972656
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 460 Average Reward: 500.0 Ep Loss: 332.040283203125
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 470 Average Reward: 500.0 Ep Loss: 442.8903503417969
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Updating Target Net
# Ep 480 Average Reward: 500.0 Ep Loss: 626.7095947265625
# Updating Target Net
# Updating Target Net
# Updating Target Net
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9f6db9b4373c> in <module>()
#     155             loss = F.mse_loss(onlineQNetwork(exp_state).gather(1, exp_action.long()), y)
#     156             optimizer.zero_grad()
# --> 157             loss.backward()
#     158             optimizer.step()
#     159             episode_loss+= loss
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#epsilon decay graph
epsilons = []
epsilon = INITIAL_EPSILON
for i in range(epoch):
  if epsilon > FINAL_EPSILON:
    epsilon *= EPSILON_DECAY
  else:
    epsilon = FINAL_EPSILON
  epsilons.append(epsilon)


plt.plot(epsilons)
plt.title('Epsilon Decay Graph')
plt.xlabel('Episode Number')
plt.ylabel('Epsilon Value')
plt.show()

# %%
#rewards graph
plt.plot(totalreward)
plt.title('Total Rewards Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Rewards')
plt.show()

# %%
onlineQNetwork = QNetwork().to(device)
onlineQNetwork.load_state_dict(torch.load('dqn-policy.pt'))
targetQNetwork = QNetwork().to(device)
targetQNetwork.load_state_dict(onlineQNetwork.state_dict())


#Optimizer

optimizer = torch.optim.Adam(onlineQNetwork.parameters(), lr=1e-4)


#Hyperparameters 
GAMMA = 0.99

REPLAY_MEMORY = 50000 # size of replay buffer
BATCH = 128 # minibatch size


UPDATE_EVERY = 4 


# graphing
totalreward_train=[]
losses_train = []

memory_replay = Memory(REPLAY_MEMORY)


learn_steps = 0

episode_reward = 0

for epoch in range(5):

    state = env.reset()
    episode_reward = 0
    for time_steps in range(500):
      # uncomment to render
        # env.render()
        tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
        action = onlineQNetwork.select_action(tensor_state)               #argmax action
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward

        if done:
            break
        state = next_state

    totalreward_train.append(episode_reward)

    print('Ep {}\Average Reward: {:.2f}\t'.format(epoch, episode_reward))
# Out:
# Ep 0\Average Reward: 500.00
# Ep 1\Average Reward: 500.00
# Ep 2\Average Reward: 500.00
# Ep 3\Average Reward: 500.00
# Ep 4\Average Reward: 500.00

# %%
#rewards graph for eval
plt.plot(totalreward_train)
plt.title('Total Rewards while Evaluating')
plt.xlabel('Episode')
plt.ylabel('Rewards')
plt.show()

# %%
class QNetwork(nn.Module):
    def __init__(self):
        super(QNetwork, self).__init__()

        #fully connected layers
        self.fc1 = nn.Linear(4, 32) #4 states
        self.relu = nn.ReLU()
        self.fc_value = nn.Linear(32, 64)
        self.fc_adv = nn.Linear(32, 64)

        self.value = nn.Linear(64, 1) # value function
        self.adv = nn.Linear(64, 2) # advantage function

    def forward(self, state):
        y = self.relu(self.fc1(state))
        value = self.relu(self.fc_value(y))
        adv = self.relu(self.fc_adv(y))

        value = self.value(value)
        adv = self.adv(adv)

        advAverage = torch.mean(adv, dim=1, keepdim=True)
        Q = value + adv - advAverage
        return Q

    def select_action(self, state):
        with torch.no_grad():
            Q = self.forward(state)
            action_index = torch.argmax(Q, dim=1)
        return action_index.item()

# The official Pytorch documentation has a class implementation of the ReplayBuffer. The implementation inspired me to make something and hence it is similar to the official one.

class Memory(object):
    def __init__(self, buffer_size: int) -> None:
        self.buffer_size = buffer_size
        self.buffer = deque(maxlen=self.buffer_size)

    def add(self, experience) -> None:
        self.buffer.append(experience)

    def size(self):
        return len(self.buffer)

    #making random memory
    def sample(self, batch_size: int, continuous: bool = True):
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
            #continuous floats
        if continuous:
            rand = random.randint(0, len(self.buffer) - batch_size)
            return [self.buffer[i] for i in range(rand, rand + batch_size)]
          #random ints
        else:
            indexes = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
            return [self.buffer[i] for i in indexes]

    def clear(self):
        self.buffer.clear()


# Cartpole-v1 is solved when:
#     max_episode_steps=500,
#     reward_threshold=475.0

env = gym.make('CartPole-v1')
n_state = env.observation_space.shape[0]
n_action = env.action_space.n

onlineQNetwork = QNetwork().to(device)

if(os.path.isfile('dueling-dqn-policy.pt')):
  onlineQNetwork.load_state_dict(torch.load('dueling-dqn-policy.pt'))

targetQNetwork = QNetwork().to(device)
targetQNetwork.load_state_dict(onlineQNetwork.state_dict())


# Hyperparameters 
GAMMA = 0.99
INITIAL_EPSILON = 0.9 #epsilon starting value
FINAL_EPSILON = 0.001 # minimum value of epsilon
EPSILON_DECAY = 0.980 # decay
BUFFER_SIZE = 50000 # size of replay buffer
BATCH = 128 # minibatch size
LR = 1e-4

# Using Adam with a Learning Rate of 0.0001
optimizer = torch.optim.Adam(onlineQNetwork.parameters(), lr=LR)

#Flow:
# Loop till done else break
# Select action based on epsilon
# Take action
# Add result to replay buffer
# If buffer size > minibatch (Train TargetNet every 1000 steps)
# Update Q network
# Perform Loss
# Perform Epsilon Decay



UPDATE_EVERY = 100


# graphing
totalreward=[]
losses = []

replay_buffer = Memory(BUFFER_SIZE)

epsilon = INITIAL_EPSILON
steps = 0

episode_reward = 0

for epoch in count():

    state = env.reset()
    episode_reward = 0
    episode_loss = 0
    for time_steps in range(500): #env states max 500 steps allowed
        p = random.random()
        if p < epsilon:
            action = random.randint(0, 1) #random action
        else:
            tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
            action = onlineQNetwork.select_action(tensor_state)               #argmax action
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward
        replay_buffer.add((state, next_state, action, reward, done))
        if replay_buffer.size() > 128:
            steps += 1

            #updating target network over every 1000 steps (OpenAIBaseline)
            if steps % UPDATE_EVERY == 0:
                targetQNetwork.load_state_dict(onlineQNetwork.state_dict())
                print("Updating Target Network")
            experience = replay_buffer.sample(BATCH, False)
            exp_state, exp_next_state, exp_action, exp_reward, exp_done = zip(*experience)
            # 'Unzipping' individual tuples

            #Converting experience to Tensors 

            exp_state = torch.FloatTensor(exp_state).to(device)
            exp_next_state = torch.FloatTensor(exp_next_state).to(device)
            exp_action = torch.FloatTensor(exp_action).unsqueeze(1).to(device)
            exp_reward = torch.FloatTensor(exp_reward).unsqueeze(1).to(device)
            exp_done = torch.FloatTensor(exp_done).unsqueeze(1).to(device)

            with torch.no_grad():
                targetQ_next = targetQNetwork(exp_next_state)
                y = exp_reward + (1 - exp_done) * GAMMA * torch.max(targetQ_next, dim=1, keepdim=True)[0] #DQN Update step


            # Simple MSE Loss
            loss = F.mse_loss(onlineQNetwork(exp_state).gather(1, exp_action.long()), y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            episode_loss+=loss
            
            # epsilon decay
            if epsilon > FINAL_EPSILON:
                epsilon *= EPSILON_DECAY
            else:
                epsilon = FINAL_EPSILON

        if done:
            break
        state = next_state

    losses.append(episode_loss)
    if epoch==1000: #for the purpose of a test run else could run till infinity
      break
    totalreward.append(episode_reward)

    if epoch % 10 == 0:
        torch.save(onlineQNetwork.state_dict(), 'dueling-dqn-policy.pt') #saving learning policy every 10 epochs
        print(f'Ep {epoch} Average Reward: {episode_reward} Ep Loss: {episode_loss}')
# Out:
# Ep 0 Average Reward: 22.0 Ep Loss: 0
# Ep 10 Average Reward: 11.0 Ep Loss: 9.1103515625
# Updating Target Network
# Ep 20 Average Reward: 9.0 Ep Loss: 6.606117248535156
# Updating Target Network
# Ep 30 Average Reward: 9.0 Ep Loss: 7.5431294441223145
# Updating Target Network
# Ep 40 Average Reward: 9.0 Ep Loss: 10.587557792663574
# Updating Target Network
# Ep 50 Average Reward: 10.0 Ep Loss: 13.57103157043457
# Updating Target Network
# Ep 60 Average Reward: 10.0 Ep Loss: 16.574172973632812
# Updating Target Network
# Ep 70 Average Reward: 9.0 Ep Loss: 17.03470802307129
# Updating Target Network
# Ep 80 Average Reward: 10.0 Ep Loss: 22.95876693725586
# Updating Target Network
# Ep 90 Average Reward: 9.0 Ep Loss: 23.918498992919922
# Updating Target Network
# Ep 100 Average Reward: 10.0 Ep Loss: 28.442607879638672
# Updating Target Network
# Ep 110 Average Reward: 10.0 Ep Loss: 27.74297332763672
# Updating Target Network
# Ep 120 Average Reward: 10.0 Ep Loss: 26.035112380981445
# Updating Target Network
# Ep 130 Average Reward: 10.0 Ep Loss: 23.814626693725586
# Updating Target Network
# Ep 140 Average Reward: 8.0 Ep Loss: 15.295354843139648
# Ep 150 Average Reward: 10.0 Ep Loss: 15.344812393188477
# Updating Target Network
# Ep 160 Average Reward: 10.0 Ep Loss: 13.451212882995605
# Updating Target Network
# Ep 170 Average Reward: 11.0 Ep Loss: 9.978255271911621
# Updating Target Network
# Ep 180 Average Reward: 9.0 Ep Loss: 10.027839660644531
# Updating Target Network
# Ep 190 Average Reward: 10.0 Ep Loss: 8.350785255432129
# Updating Target Network
# Ep 200 Average Reward: 11.0 Ep Loss: 7.358428001403809
# Updating Target Network
# Ep 210 Average Reward: 10.0 Ep Loss: 9.191875457763672
# Updating Target Network
# Ep 220 Average Reward: 9.0 Ep Loss: 35.41606140136719
# Updating Target Network
# Ep 230 Average Reward: 9.0 Ep Loss: 75.43489837646484
# Updating Target Network
# Ep 240 Average Reward: 9.0 Ep Loss: 146.0848388671875
# Updating Target Network
# Ep 250 Average Reward: 8.0 Ep Loss: 156.9792938232422
# Updating Target Network
# Ep 260 Average Reward: 9.0 Ep Loss: 170.38404846191406
# Updating Target Network
# Ep 270 Average Reward: 9.0 Ep Loss: 136.1054229736328
# Updating Target Network
# Ep 280 Average Reward: 9.0 Ep Loss: 137.26443481445312
# Updating Target Network
# Ep 290 Average Reward: 9.0 Ep Loss: 83.16160583496094
# Updating Target Network
# Ep 300 Average Reward: 9.0 Ep Loss: 80.93247985839844
# Updating Target Network
# Ep 310 Average Reward: 8.0 Ep Loss: 61.61762237548828
# Updating Target Network
# Ep 320 Average Reward: 9.0 Ep Loss: 53.47999572753906
# Updating Target Network
# Ep 330 Average Reward: 9.0 Ep Loss: 35.96110153198242
# Updating Target Network
# Ep 340 Average Reward: 9.0 Ep Loss: 39.29974365234375
# Updating Target Network
# Ep 350 Average Reward: 10.0 Ep Loss: 28.35039520263672
# Ep 360 Average Reward: 9.0 Ep Loss: 17.05099868774414
# Updating Target Network
# Ep 370 Average Reward: 9.0 Ep Loss: 10.099895477294922
# Updating Target Network
# Ep 380 Average Reward: 9.0 Ep Loss: 9.789807319641113
# Updating Target Network
# Ep 390 Average Reward: 12.0 Ep Loss: 10.679183959960938
# Updating Target Network
# Ep 400 Average Reward: 10.0 Ep Loss: 11.590046882629395
# Updating Target Network
# Updating Target Network
# Ep 410 Average Reward: 12.0 Ep Loss: 18.291215896606445
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 420 Average Reward: 36.0 Ep Loss: 54.604244232177734
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 430 Average Reward: 28.0 Ep Loss: 50.9225959777832
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 440 Average Reward: 47.0 Ep Loss: 120.24553680419922
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 450 Average Reward: 62.0 Ep Loss: 189.5607147216797
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 460 Average Reward: 83.0 Ep Loss: 344.8554992675781
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 470 Average Reward: 75.0 Ep Loss: 460.0167541503906
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 480 Average Reward: 96.0 Ep Loss: 600.89111328125
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 490 Average Reward: 68.0 Ep Loss: 548.7760009765625
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 500 Average Reward: 94.0 Ep Loss: 871.7080688476562
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 510 Average Reward: 83.0 Ep Loss: 713.1630249023438
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 520 Average Reward: 83.0 Ep Loss: 567.3690795898438
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 530 Average Reward: 110.0 Ep Loss: 917.0814819335938
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 540 Average Reward: 90.0 Ep Loss: 794.533447265625
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 550 Average Reward: 143.0 Ep Loss: 1149.8883056640625
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 560 Average Reward: 162.0 Ep Loss: 1021.7067260742188
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 570 Average Reward: 136.0 Ep Loss: 989.5846557617188
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 580 Average Reward: 99.0 Ep Loss: 519.3916015625
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 590 Average Reward: 500.0 Ep Loss: 2759.254638671875
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 600 Average Reward: 500.0 Ep Loss: 2556.46044921875
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 610 Average Reward: 291.0 Ep Loss: 1519.84326171875
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 620 Average Reward: 272.0 Ep Loss: 2311.820068359375
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Ep 630 Average Reward: 500.0 Ep Loss: 13551.9462890625
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# Updating Target Network
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-9ee2d74c4be0> in <module>()
#     155
#     156             # Simple MSE Loss
# --> 157             loss = F.mse_loss(onlineQNetwork(exp_state).gather(1, exp_action.long()), y)
#     158             optimizer.zero_grad()
#     159             loss.backward()
#
# KeyboardInterrupt:

# %%
#rewards graph
plt.plot(totalreward)
plt.title('Total Rewards Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Rewards')
plt.show()

# %%
onlineQNetwork = QNetwork().to(device)
onlineQNetwork.load_state_dict(torch.load('dueling-dqn-policy.pt'))
targetQNetwork = QNetwork().to(device)
targetQNetwork.load_state_dict(onlineQNetwork.state_dict())


#Optimizer

optimizer = torch.optim.Adam(onlineQNetwork.parameters(), lr=1e-4)


#Hyperparameters 
GAMMA = 0.99

REPLAY_MEMORY = 50000 # size of replay buffer
BATCH = 128 # minibatch size


UPDATE_EVERY = 4 


# graphing
totalreward_train=[]
losses_train = []

memory_replay = Memory(REPLAY_MEMORY)


learn_steps = 0

episode_reward = 0

for epoch in range(5):

    state = env.reset()
    episode_reward = 0
    for time_steps in range(500):
      # uncomment to render
        # env.render()
        tensor_state = torch.FloatTensor(state).unsqueeze(0).to(device)
        action = onlineQNetwork.select_action(tensor_state)               #argmax action
        next_state, reward, done, _ = env.step(action)
        episode_reward += reward

        if done:
            break
        state = next_state

    totalreward_train.append(episode_reward)

    print('Ep {}\Average Reward: {:.2f}\t'.format(epoch, episode_reward))
# Out:
# Ep 0\Average Reward: 500.00
# Ep 1\Average Reward: 500.00
# Ep 2\Average Reward: 500.00
# Ep 3\Average Reward: 500.00
# Ep 4\Average Reward: 500.00

# %%
#rewards graph for eval
plt.plot(totalreward_train)
plt.title('Total Rewards while Evaluating')
plt.xlabel('Episode')
plt.ylabel('Rewards')
plt.show()
